# %%
#!/usr/bin/env python
#!coding: utf-8 



import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


import pandas as pd
from google.oauth2.credentials import Credentials

from googleapiclient.discovery import build


from google.oauth2 import service_account
def get_sheet(id):
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
    SERVICE_ACCOUNT_FILE = 'keys.json'

    creds = None
    creds = service_account.Credentials.from_service_account_file(
            SERVICE_ACCOUNT_FILE,scopes=SCOPES)

    # If modifying these scopes, delete the file token.json.
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

    # The ID and range of a sample spreadsheet.
    SAMPLE_SPREADSHEET_ID = id







    service = build('sheets', 'v4', credentials=creds)

            # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                        range='A1:M100').execute()
    values = result.get('values', [])
    
    df = pd.DataFrame(values[1:], columns=values[0])
    return df

#get_sheet('1wMi1a_Igifrz4MtM4nsbXA-SAl7Mo9uO85nVpW-rL_Q')

def add_date(df):
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    df['month']=df['Timestamp'].dt.month
    df['day']=df['Timestamp'].dt.day
    df['year']=df['Timestamp'].dt.year
    return df


def rename(df):
    try:
        df['name'] = df['لطفا نام خود را وارد نمائید'] 
        df['personal'] = df['لطفا کد پرسنلی خود را ثبت نمائید.'] 
        df['team'] = df['لطفا واحدی که در آن مشغول به فعالیت می باشید را انتخاب نمائید.']
        df['description'] = df['لطفا پیشنهاد خود را شرح دهید:']
        df['field'] = df["پیشنهاد شما در چه حوزه ای می باشد؟"]
        df['documentation'] = df['در صورت نیاز به بارگزاری مستندات برای شفافیت موضوع خود، میتوانید از این قسمت استفاده نمائید.']
        df['Timestamp'] = df['Timestamp'].dt.date
    except : pass
    #del df['لطفا نام خود را وارد نمائید'], df['لطفا کد پرسنلی خود را ثبت نمائید.'],df['لطفا واحدی که در آن مشغول به فعالیت می باشید را انتخاب نمائید.'],df['لطفا پیشنهاد خود را شرح دهید:'],df["پیشنهاد شما در چه حوزه ای می باشد؟"],df['در صورت نیاز به بارگزاری مستندات برای شفافیت موضوع خود، میتوانید از این قسمت استفاده نمائید.']
    
    return df


def preprocessing(df):

    #df['peronal'] = df['peronal'].astype(int)
    df['name'] = df['name'].astype(str)
    df['team'] = df['team'].astype(str)
    df['field'] = df['field'].map({'پیشنهاد بهبود (اصلاح رویه- ایجاد رویه جدید)':'suggestion','تولید محتوا':'content','باگ':'bug'})

    
    return df


#!/usr/bin/env python
#coding: utf-8 

def main():
    df = get_sheet('1wMi1a_Igifrz4MtM4nsbXA-SAl7Mo9uO85nVpW-rL_Q')
    df = add_date(df)
    df = rename(df)
    df = preprocessing(df)
    
    sns.countplot(data = df,x = df.field)
    plt.title('field separated',fontsize=20)
    plt.show()
    
    fig=plt.figure(figsize=(10,5))
    ax=sns.countplot(data = df,x = df.field,hue=df.team)
    ax.tick_params(axis='x', rotation=60)
    plt.title('team separated',fontsize=20)
    plt.show()

    plt.figure(figsize=(8,5))
    plt.plot(df.groupby('Timestamp')['personal'].count(),c='green')
    plt.xlabel('Date')
    plt.ylabel("# of reported issues")
    plt.show()
    df.groupby(["team","field"]).size().unstack().sort_values(by=["team"],ascending=False).plot(kind='bar', stacked=True, figsize=(7,7))

    print(pd.DataFrame(pd.crosstab(df.personal,df.field)).head(10))
   
   
    


if __name__ == '__main__':
    main()
# Out:
# field     bug  content  suggestion
# personal
# 11398       2        4           2
# 11536       0        0           1
# 12274       1        0           1
# 1234        1        0           0
# 12948       0        0           1
# 13858       0        1           0
# 15181       0        0           1
# 15709       1        0           1
# 15767       2        0           6
# 1688        0        0           1

# %%
df = get_sheet('1wMi1a_Igifrz4MtM4nsbXA-SAl7Mo9uO85nVpW-rL_Q')
df = add_date(df)
df = rename(df)
df=preprocessing(df)

# %%
df.groupby(["team","field"]).size().unstack()
# Out:
# field           bug  content  suggestion
# team
# CA              NaN      NaN         1.0
# Case Followup   6.0      2.0        17.0
# Chat            2.0      1.0         2.0
# Digi-Express    1.0      NaN         2.0
# Digikala Jet    1.0      3.0         2.0
# Front           5.0      7.0         8.0
# Plus+           6.0      1.0        10.0
# Project         NaN      NaN         2.0
# QA              NaN      NaN         1.0
# Seller support  NaN      NaN         1.0
# Social Media    3.0      NaN         3.0
# Ticket          4.0      1.0         1.0

# %%
df.groupby(["team","field"]).size().unstack().sort_values(by=["team"],ascending=False).plot(kind='bar', stacked=True, figsize=(7,7))
# Out:
# <AxesSubplot:xlabel='team'>

# %%
sns.countplot(data = df,x = df.field)
plt.title('field separated',fontsize=20)
plt.show()

# %%
fig=plt.figure(figsize=(10,5))
ax=sns.countplot(data = df,x = df.field,hue=df.team)
ax.tick_params(axis='x', rotation=60)
plt.title('team separated',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df.groupby('Timestamp')['personal'].count(),c='green')
plt.xlabel('Date')
plt.ylabel("# of reported issues")
plt.show()

# %%
#fig,axes = plt.subplots(2,3,figsize=(12,12),sharex=True,sharey=True)


top = pd.DataFrame(df.personal.value_counts().sort_values(ascending=False))
#top['# of suggested issues till now']=top['personal']
#del top['personal']

#top.index = [x for x in range(1, len(top.personal)+1)]

# %%
top['# of suggested issues till now']=top['personal']
del top['personal']

# %%
df.groupby(["personal","field"]).size().unstack().sort_values(by=["personal"],ascending=True).head(10)
# Out:
# field     bug  content  suggestion
# personal
# 11398     2.0      4.0         2.0
# 11536     NaN      NaN         1.0
# 12274     1.0      NaN         NaN
# 1234      1.0      NaN         NaN
# 12948     NaN      NaN         1.0
# 13858     NaN      1.0         NaN
# 15181     NaN      NaN         1.0
# 15709     1.0      NaN         1.0
# 15767     2.0      NaN         5.0
# 1688      NaN      NaN         1.0

# %%
df.head(2)
# Out:
#     Timestamp لطفا نام خود را وارد نمائید لطفا کد پرسنلی خود را ثبت نمائید.  \
# 0  2022-08-29                   مستر همفر                              1234
# 1  2022-08-29                 علی بیک پور                              7462
#
#   لطفا واحدی که در آن مشغول به فعالیت می باشید را انتخاب نمائید.  \
# 0                                              Front
# 1                                              Front
#
#             پیشنهاد شما در چه حوزه ای می باشد؟  \
# 0                                          باگ
# 1  پیشنهاد بهبود (اصلاح رویه- ایجاد رویه جدید)
#
#                        لطفا پیشنهاد خود را شرح دهید:  \
# 0  حقوق کمه؛ حقوق ما رو بیشتر کنید همه چی میفته ر...
# 1  I)Objective : Improve CX ( in order to Improve...
#
#   در صورت نیاز به بارگزاری مستندات برای شفافیت موضوع خود، میتوانید از این قسمت استفاده نمائید.  \
# 0  https://drive.google.com/open?id=1YyYUIUM1zKxx...
# 1  https://drive.google.com/open?id=1RhifEHUcwW5a...
#
#    month  day  year         name personal   team  \
# 0      8   29  2022    مستر همفر     1234  Front
# 1      8   29  2022  علی بیک پور     7462  Front
#
#                                          description       field  \
# 0  حقوق کمه؛ حقوق ما رو بیشتر کنید همه چی میفته ر...         bug
# 1  I)Objective : Improve CX ( in order to Improve...  suggestion
#
#                                        documentation
# 0  https://drive.google.com/open?id=1YyYUIUM1zKxx...
# 1  https://drive.google.com/open?id=1RhifEHUcwW5a...

# %%
pd.DataFrame(pd.crosstab(df.personal,df.field)).head(10)
# Out:
# field     bug  content  suggestion
# personal
# 11398       2        4           2
# 11536       0        0           1
# 12274       1        0           0
# 1234        1        0           0
# 12948       0        0           1
# 13858       0        1           0
# 15181       0        0           1
# 15709       1        0           1
# 15767       2        0           4
# 1688        0        0           1

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
from wordcloud_fa import WordCloudFa

# %%
from wordcloud_fa import WordCloudFa
wc = WordCloudFa()

# %%
text = 'این یک متن تستی است'

# %%
text
# Out:
# 'این یک متن تستی است'

# %%
from __future__ import unicode_literals
from hazm import *

# %%
normalizer = Normalizer()
normalizer.normalize('اصلاح نويسه ها و استفاده از نیم‌فاصله پردازش را آسان مي كند')
'اصلاح نویسه‌ها و استفاده از نیم‌فاصله پردازش را آسان می‌کند'
# Out:
# 'اصلاح نویسه\u200cها و استفاده از نیم\u200cفاصله پردازش را آسان می\u200cکند'

# %%
word_tokenize('')
# Out:
# ['ولی', 'برای', 'پردازش', '،', 'جدا', 'بهتر', 'نیست', '؟']

# %%
with open('test.txt', 'r',encoding="utf-8") as file:
    text = file.read()

# %%
text = 'اصلاح نويسه ها و استفاده از نیم‌فاصله پردازش را آسان مي كند'

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text =

# %%
text
# Out:
# 'اصلاح نويسه ها و استفاده از نیم\u200cفاصله پردازش را آسان مي كند'

# %%
wordcloud = WordCloud().generate(text)

# %%
plt.imshow(wordcloud)

# %%
from wordcloud_fa import WordCloudFa
text = 'این یک متن تستی است'
wc = WordCloudFa(persian_normalize=True, no_reshape=True, background_color="white", width=1000, height=500)
word_cloud = wc.generate(text)
image = word_cloud.to_image()
image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 from wordcloud_fa import WordCloudFa
#       2 text = 'این یک متن تستی است'
#       3 wc = WordCloudFa(persian_normalize=True, no_reshape=True, background_color="white", width=1000, height=500)
#
# ModuleNotFoundError: No module named 'wordcloud_fa'

# %%
! pip install wordcloud-fa
# Out:
# Collecting wordcloud-fa
#   Using cached wordcloud_fa-0.1.9-py2.py3-none-any.whl (71 kB)
# Requirement already satisfied: pillow>=7.0.0 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from wordcloud-fa) (9.2.0)
# Requirement already satisfied: arabic-reshaper>=2.1.3 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from wordcloud-fa) (2.1.3)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from wordcloud-fa) (1.23.2)
# Requirement already satisfied: matplotlib>=3.1.2 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from wordcloud-fa) (3.5.3)
# Requirement already satisfied: python-bidi==0.4.2 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from wordcloud-fa) (0.4.2)
# Requirement already satisfied: hazm==0.7.0 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from wordcloud-fa) (0.7.0)
# Collecting wordcloud==1.8.1
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk==3.3 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from hazm==0.7.0->wordcloud-fa) (3.3)
# Requirement already satisfied: six in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from python-bidi==0.4.2->wordcloud-fa) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from arabic-reshaper>=2.1.3->wordcloud-fa) (58.2.0)
# Requirement already satisfied: future in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from arabic-reshaper>=2.1.3->wordcloud-fa) (0.18.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1.2->wordcloud-fa) (3.0.9)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: wordcloud, wordcloud-fa
#   Attempting uninstall: wordcloud
#     Found existing installation: wordcloud 1.8.2.2
#     Uninstalling wordcloud-1.8.2.2:
#       Successfully uninstalled wordcloud-1.8.2.2
#   Running setup.py install for wordcloud: started
#   Running setup.py install for wordcloud: finished with status 'error'
#   Rolling back uninstall of wordcloud
#   Moving to c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages\wordcloud-1.8.2.2.dist-info\
#    from C:\Users\a.farzanieh\AppData\Local\Programs\Python\Python310\Lib\site-packages\~ordcloud-1.8.2.2.dist-info
#   Moving to c:\users\a.farzanieh\appdata\local\programs\python\python310\lib\site-packages\wordcloud\
#    from C:\Users\a.farzanieh\AppData\Local\Programs\Python\Python310\Lib\site-packages\~-rdcloud
#   Moving to c:\users\a.farzanieh\appdata\local\programs\python\python310\scripts\wordcloud_cli.exe
#    from C:\Users\a.farzanieh\AppData\Local\Temp\pip-uninstall-3b2iogx7\wordcloud_cli.exe
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.10\wordcloud
#   UPDATING build\lib.win-amd64-3.10\wordcloud/_version.py
#   set build\lib.win-amd64-3.10\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for wordcloud
#   error: subprocess-exited-with-error
#
#   Running setup.py install for wordcloud did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   running install
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.10\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.10\wordcloud
#   UPDATING build\lib.win-amd64-3.10\wordcloud/_version.py
#   set build\lib.win-amd64-3.10\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# wordcloud
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
